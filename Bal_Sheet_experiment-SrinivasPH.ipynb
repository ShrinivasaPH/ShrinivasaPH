# %% [markdown]
# <a href="https://colab.research.google.com/github/ShrinivasaPH/ShrinivasaPH/blob/main/Bal_Sheet_experiment-SrinivasPH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date
from datetime import datetime
import seaborn as sns
from matplotlib.font_manager import FontProperties
import plotly.graph_objs as go
import plotly.express as px
import plotly.io as pio

# %%
print()
#Cash in Bank
city_bank = float(448430.24)
hdfc_bank = float(68615.52)
#cash in hand
cash_in_hand = float(1000)

cash_in_bank = city_bank + hdfc_bank
print("Summary:")
print()
print("Assets")
print("Cash in Bank:")
print(round(cash_in_bank,2))
print("Cash in hand: ")
print(round(cash_in_hand,2))
total_cash = cash_in_bank + cash_in_hand
print("Total Cash:",round(total_cash,2))
print()

#Wallets
sodexo_zeta = 0 #float(2763.95)
amazon_pay = float(272)
bns_wallet = 348.62
airTM = 1278.73
UPIlite = 0
wallets = sodexo_zeta + amazon_pay + bns_wallet + airTM + UPIlite
#investments

hdfc_security = float(10521.4) #Enter HDFC share value here 📈📉📈📉📈📉📈📉📈📉
print("HDFC Security",hdfc_security)

#providentFund
employeeShare = 0 #float(211301)
employerShare = 0 #float(82202)
provident_fund = employeeShare + employerShare
print("Provident Fund:",provident_fund)
pension_contribution = 0  #float(86116)

gold_price_per_gram = 7476.60 #24 Carat #Enter here: ✨✨✨✨✨✨

crypto_curr = float(1668.70) #Enter here: 💹💰💱
gpay_goldVault = float(gold_price_per_gram * 1.1669)

SGB = float(gold_price_per_gram *2)   #✨✨✨✨✨✨✨✨✨✨✨✨✨
investments = hdfc_security + provident_fund + crypto_curr + gpay_goldVault + SGB + pension_contribution
print("Investments:",round(investments,2))

#Debtors
debtor_mohan = 0
debtor_vijay = 0
debtors = debtor_mohan + debtor_vijay
print()

if debtors > 0:
  print("Debtors:")
  print(debtors)
  print("____________________")
  print("____________________")
else:
  print("____________________")
  print()
  print("No Debtors")
  print("____________________")

print()
print()

#Liabilities
print("Liabilities:")
print("Creditors:")
paid_installments = 20
liquiEMIPaid = float(10583.33) * paid_installments    #✨✨✨✨✨✨✨
liquiLoans = float(254000) - round(liquiEMIPaid)
print("(LiquiEMI paid:",round(liquiEMIPaid,2),")",(round((liquiEMIPaid/254000)*100)),"%")
HDFC_credit = float(0)
usha = float(0)
rajendra = 0 # float(18000) + float(7000) + float(20000) - float(30000) #BG + Adige + Haasige, Paid to Rajendra(negative balance) respectively
individualLoans =  usha + rajendra
print("liquiloans Balance:",liquiLoans, "(", round((liquiLoans/254000)*100),"%", ")" ,"Usha:",usha , "Rajendra:",rajendra)
print("HDFC Credit Card:",HDFC_credit)
creditors = liquiLoans + individualLoans + HDFC_credit

liabilities = creditors
print("____________________")
print("Your Liabilities value:")
print("Rs.",round(liabilities,2))
print("____________________")
print("____________________")

asset = (total_cash + investments + debtors + wallets) - liabilities
print("Your Gross Asset Value:","Rs.", round(asset + liabilities,2))
print("Your Net Asset Value:","Rs.",round(asset,2))
print("Your liquid asset:","Rs.",round(total_cash,2),"(Cash)")


print("____________________")
print("____________________")
print()
print()


print("Details:")
print("Shares:",hdfc_security)
print("PF :",provident_fund)
print("Pension Contribution:",pension_contribution)
print("Crypto:",crypto_curr)
print("             ")
print("Wallets:")
print("Sodexo:",sodexo_zeta)
print("Amazon Pay:",amazon_pay)
print("BNS Wallet:",bns_wallet)
print("             ")
print("             ")
print("GPay Gold Vault (1030 mgs):","Rs.",round(gpay_goldVault,2),"(Current value)")
print("At the time of investment(05-02-2023): Rs.5680")

gpay_goldVault_buyingTime = float(5680 + 201 + 1001) # Price of gold at the time of buying GpayGold
gold_Profit_loss = gpay_goldVault - gpay_goldVault_buyingTime
if gold_Profit_loss > 0:
    print("Gold Profit:","Rs.",round(gold_Profit_loss,2),"✨","(",(round((gpay_goldVault/gpay_goldVault_buyingTime) * 100-100,2)),"% ^)")
else:
    print("Gold Loss:","Rs.",round(gold_Profit_loss,2),"✨","(",(round((gpay_goldVault/gpay_goldVault_buyingTime) * 100-100,2)),"%)")

SGB_buying_time = 6213 # Price of gold at the time of buying SGB
SGB_Prof = (gold_price_per_gram * 2) - (SGB_buying_time * 2) # Profit in SGB
tot_gold_prof = round(gold_Profit_loss + SGB_Prof,2) # Total Gold Profit

print("SGB Profit:",round(SGB_Prof,2),"✨", "(",(round((gold_price_per_gram/SGB_buying_time)*100-100,2)), "% ^)")
print("Total Gold profit:",tot_gold_prof,"✨","^")
print("_____________")
print("_____________")
print("_____________")
# Out:
# Summary:
#
# Assets
# Cash in Bank:
# 517045.76
# Cash in hand:
# 1000.0
# Total Cash: 518045.76
#
# HDFC Security 10521.4
# Provident Fund: 0
# Investments: 35867.74
#
# ____________________
#
# No Debtors
# ____________________
#
#
# Liabilities:
# Creditors:
# (LiquiEMI paid: 211666.6 ) 83 %
# liquiloans Balance: 42333.0 ( 17 % ) Usha: 0.0 Rajendra: 0
# HDFC Credit Card: 0.0
# ____________________
# Your Liabilities value:
# Rs. 42333.0
# ____________________
# ____________________
# Your Gross Asset Value: Rs. 555812.85
# Your Net Asset Value: Rs. 513479.85
# Your liquid asset: Rs. 518045.76 (Cash)
# ____________________
# ____________________
#
#
# Details:
# Shares: 10521.4
# PF : 0
# Pension Contribution: 0
# Crypto: 1668.7
#
# Wallets:
# Sodexo: 0
# Amazon Pay: 272.0
# BNS Wallet: 348.62
#
#
# GPay Gold Vault (1030 mgs): Rs. 8724.44 (Current value)
# At the time of investment(05-02-2023): Rs.5680
# Gold Profit: Rs. 1842.44 ✨ ( 26.77 % ^)
# SGB Profit: 2527.2 ✨ ( 20.34 % ^)
# ...

# %%
all_Cash = pd.DataFrame({
    "Particulars": ["Cash At Bank", "Cash In Hand", "Shares", "PF", "Pension",
             "Debtors", "Gold", "Crypto", "Amazon Pay", "G UPI-Lite", "Sodexo", "BNS Wallet", "airTM", "Liqui Loans"],
    "Amount": [city_bank + hdfc_bank, cash_in_hand, hdfc_security, provident_fund, pension_contribution,
               debtors, round(gpay_goldVault + SGB,2), crypto_curr,amazon_pay, UPIlite, sodexo_zeta, bns_wallet, airTM, (liquiLoans * -1)]
})
all_Cash = all_Cash[all_Cash["Amount"] != 0]
#all_Cash = all_Cash[all_Cash["Particulars"] != 'Pension']
#all_Cash = pd.concat([all_Cash, pd.DataFrame({'Particulars':['Total Cash'], 'Amount': [all_Cash['Amount'].sum()]})], ignore_index=True)
all_Cash
# Out:
#      Particulars     Amount
# 0   Cash At Bank  517045.76
# 1   Cash In Hand    1000.00
# 2         Shares   10521.40
# 6           Gold   23677.64
# 7         Crypto    1668.70
# 8     Amazon Pay     272.00
# 11    BNS Wallet     348.62
# 12         airTM    1278.73
# 13   Liqui Loans  -42333.00

# %%
print("All Cash Total:")
print(round(all_Cash["Amount"].sum() + liquiLoans)) # LiquiLoans is already diducted in negative
# Out:
# All Cash Total:
# 555813

# %%
#all_Cash.to_csv('all_Cash_file.csv', index=False)

# %%
# Sample data
categories = all_Cash['Particulars']
values = round(all_Cash['Amount'],2)

# Create a bar trace
trace = go.Bar(
    x=categories,
    y=values,
    text=values,  # This will display the values atop the bars
    marker=dict(color='#4763B9')  # Color of the bars
)

# Create layout with an interactive feature
layout = go.Layout(
    title='--- Balance Sheet ---',  # Title of the chart
    xaxis=dict(title='Particulars'),     # Label for x-axis
    yaxis=dict(title='Amount'),     # Label for y-axis
    hovermode='closest',             # Show hover labels
    autosize=True
)

# Create figure
fig = go.Figure(data=[trace], layout=layout)

# Display the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(" Gross Assets:         ",round(all_Cash["Amount"].sum() + liquiLoans ,2))
print(" Liabilities:          ",round((liquiLoans)*(-1),2))
print(" ---------------------------------")
print("| Net Assets:          ",round(all_Cash["Amount"].sum(),2)," | ✨✨✨✨✨")
print(" --------------------------------- ")
# Out:
#  Gross Assets:          555812.85
#  Liabilities:           -42333.0
#  ---------------------------------
# | Net Assets:           513479.85  | ✨✨✨✨✨
#  ---------------------------------

# %%
round(all_Cash["Amount"].sum())
# Out:
# 513480

# %%
#Cash & PF

print("Major categories:")
print()
cash_PF = round(total_cash + provident_fund + pension_contribution, 2)
print("Cash + PF + Pension:",cash_PF,sep='\n')
# Out:
# Major categories:
#
# Cash + PF + Pension:
# 518045.76

# %%
#Liquid asset apart from Cash
LA = pd.DataFrame({
    "Investment Name":  ["Shares", "GPay Gold", "Crypto", "BNS Wallet"],
    "Amount": [round(hdfc_security,2), round(gpay_goldVault,2), round(crypto_curr,2), round(bns_wallet,2)]
})
LA
# Out:
#   Investment Name    Amount
# 0          Shares  10521.40
# 1       GPay Gold   8724.44
# 2          Crypto   1668.70
# 3      BNS Wallet    348.62

# %%
fig = px.bar(LA, x='Investment Name', y='Amount', title='Liquid Assets', text=LA['Amount'].apply(lambda x: f'{x:,.02f}'), color_discrete_sequence=['#334783'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#asset vs liab viz

# %% [markdown]
# **Net Valuation**

# %%
Gross_Assets = pd.DataFrame({
    "Asset Name" : ["Total Cash", "Investments", "Debtors", "Sodexo", "Amazon Pay"],
    "Amount" : [round(total_cash,2), round(investments,2), round(debtors,2), round(sodexo_zeta,2), round(amazon_pay,2)]
})
Gross_Assets = Gross_Assets[Gross_Assets["Amount"] != 0]
Gross_Assets = pd.concat([Gross_Assets, pd.DataFrame({'Asset Name': ['Total Gross Asset'], 'Amount': [Gross_Assets['Amount'].sum()]})], ignore_index=True)
Gross_Assets
# Out:
#           Asset Name     Amount
# 0         Total Cash  518045.76
# 1        Investments   35867.74
# 2         Amazon Pay     272.00
# 3  Total Gross Asset  554185.50

# %%
Net_Assets = pd.DataFrame({
    "Asset Name" : ["Total Cash", "Investments", "Debtors", "Wallets", "Liabilities"],
    "Amount" : [round(total_cash,2), round(investments,2), round(debtors,2), round(wallets,2), round((liabilities * (-1)),2)]
})
Net_Assets = Net_Assets[Net_Assets["Amount"] != 0]
Net_Assets = pd.concat([Net_Assets, pd.DataFrame({'Asset Name': ['Total Net Asset'], 'Amount': [Net_Assets['Amount'].sum()]})], ignore_index=True)
Net_Assets
# Out:
#         Asset Name     Amount
# 0       Total Cash  518045.76
# 1      Investments   35867.74
# 2          Wallets    1899.35
# 3      Liabilities  -42333.00
# 4  Total Net Asset  513479.85

# %%
print("Net assets with gold profit:",round(all_Cash["Amount"].sum(),2))
print("Net assets without gold profit:", round(all_Cash["Amount"].sum() - tot_gold_prof,2))
print("Difference/Profit:", tot_gold_prof)
# Out:
# Net assets with gold profit: 513479.85
# Net assets without gold profit: 509110.21
# Difference/Profit: 4369.64

# %%
#Provident Fund
pf_money = pd.DataFrame({
    "Type": ["Employee Share", "Employer Share", "Pension"],
    "Amount": [employeeShare, employerShare, pension_contribution]
})
pf_money = pd.concat([pf_money, pd.DataFrame({'Type': ['Total PF'], 'Amount': [pf_money['Amount'].sum()]})], ignore_index=True)
pf_money
# Out:
#              Type  Amount
# 0  Employee Share       0
# 1  Employer Share       0
# 2         Pension       0
# 3        Total PF       0

# %%
#Overall investments

inv = pd.DataFrame({
    "Investment": ["HDFC Security", "Provident Fund", "Pension", "Crypto Currency", "Gold"],
    "Amount": [hdfc_security, provident_fund, pension_contribution, crypto_curr, round(gpay_goldVault + SGB,2)]
})
inv = inv.loc[inv["Amount"] != 0]
#inv = pd.concat([inv, pd.DataFrame({'Investment': ['Total Investments'], 'Amount': [inv['Amount'].sum()]})], ignore_index=True)
inv
# Out:
#         Investment    Amount
# 0    HDFC Security  10521.40
# 3  Crypto Currency   1668.70
# 4             Gold  23677.64

# %%
# Sample data
categories = inv["Investment"]
values = inv["Amount"]

# Create a bar trace
trace = go.Bar(
    x=categories,
    y=values,
    text=values,  # This will display the values atop the bars
    marker=dict(color='#334783')  # Color of the bars
)

# Create layout with an interactive feature
layout = go.Layout(
    title='--- Investment Plot ---',  # Title of the chart
    xaxis=dict(title='Particulars'),     # Label for x-axis
    yaxis=dict(title='Amount'),     # Label for y-axis
    hovermode='closest',             # Show hover labels
    extendfunnelareacolors=True
)

# Create figure
fig = go.Figure(data=[trace], layout=layout)

# Display the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Cash vs Investments
labels = ["Total Cash", "Investments"]
values = [total_cash, (round(investments,2))]

# Define a function for custom percentage display
def func(pct, allvalues):
    absolute = round(np.sum(allvalues) * pct / 100.0, 2)
    return f"{pct:.1f}%<br>(₹{absolute:.2f})"

# Define pie chart trace
trace = go.Pie(labels=labels, values=values, hole=0.3,
               textinfo='percent+value', textposition='inside',
               hoverinfo='label+percent+value',
               marker=dict(colors=['majenta', 'black'], line=dict(color='white', width=2)))

# Define layout
layout = go.Layout(title="--- Distribution of Cash VS Investments ---", titlefont=dict(size=16, color='black'),
                   legend=dict(font=dict(size=12), bgcolor='rgba(0,0,0,0)', bordercolor='rgba(0,0,0,0)'),
                   margin=dict(l=50, r=50, t=50, b=50), autosize=True)

# Create figure
fig = go.Figure(data=[trace], layout=layout)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Cash vs Investments
term = 24
labels = ["Balance", "Cleared", "Remaining Installments"]
values = [liquiLoans, liquiEMIPaid, (term - paid_installments)]
remaining_installments = term - paid_installments

# Calculate total sum
total_sum = np.sum(values)

# Define pie chart trace
trace = go.Pie(labels=labels, values=values, hole=0.3,
               textinfo='percent+value', textposition='inside',
               hoverinfo='label+percent+value',
               texttemplate='%{percent:.1%}<br>₹%{value:.2f}<br>Inst: %{customdata}',
               customdata=[remaining_installments, paid_installments, remaining_installments],
               marker=dict(colors=['violet', 'black'], line=dict(color='white', width=2)))

# Add total sum as annotation
annotation = [dict(text=f'LiquiLoan:<br>₹ {round(total_sum - remaining_installments)}', showarrow=False)]

# Define layout with annotation
layout = go.Layout(title="--- LiquiLoans Balance ---", titlefont=dict(size=16, color='black'),
                   legend=dict(font=dict(size=12), bgcolor='rgba(0.5,0,0.9,0)', bordercolor='rgba(0.4,0.9,0,0)'),
                   margin=dict(l=50, r=50, t=50, b=50), autosize=True,
                   annotations=annotation)

# Create figure
fig = go.Figure(data=[trace], layout=layout)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Cash details
cash = pd.DataFrame({
    "Bank":["Citi Bank", "HDFC Bank", "Cash in Hand"],
    "Amount":[city_bank, hdfc_bank, cash_in_hand]})
cash
# Out:
#            Bank     Amount
# 0     Citi Bank  448430.24
# 1     HDFC Bank   68615.52
# 2  Cash in Hand    1000.00

# %%
#Total Cash
print("Total Cash:")
round(cash["Amount"].sum(),2)
# Out:
# Total Cash:
# 518045.76

# %%
from dateutil.relativedelta import relativedelta
from datetime import date
import pandas as pd

# Assuming the following variables are defined:
# gpay_goldVault_buyingTime, gpay_goldVault, gold_Profit_loss

gold = pd.DataFrame({
    'Buying Price' : gpay_goldVault_buyingTime,
    'Current Price' : round(gpay_goldVault, 2),
    'Buy Date' : ['2023-02-05'],
    'Today' : [date.today()],
    'Profit' : round(gold_Profit_loss, 2),
    'Up%^ ✨' : round((gpay_goldVault / gpay_goldVault_buyingTime) * 100 - 100, 2),
    'Duration': ''
})

# Convert 'Buy Date' and 'Today' to datetime
gold["Buy Date"] = pd.to_datetime(gold['Buy Date'])
gold["Today"] = pd.to_datetime(gold['Today'])

# Calculate duration in years and months using relativedelta
gold['Duration'] = gold.apply(lambda row: relativedelta(row['Today'], row['Buy Date']), axis=1)

# Format the duration to show as "X years Y months" or "X months" if no years
gold['Duration'] = gold['Duration'].apply(lambda x: f"{x.years} years, {x.months} months" if x.years > 0 else f"{x.months} months")

gold
# Out:
#    Buying Price  Current Price   Buy Date      Today   Profit  Up%^ ✨  \
# 0        6882.0        8724.44 2023-02-05 2024-11-13  1842.44   26.77
#
#             Duration
# 0  1 years, 9 months

# %%
# SGB Table

gold_SGB = pd.DataFrame({
    "Today" :  [date.today()],
    "Buying Price" : SGB_buying_time,
    "Current Price" : gold_price_per_gram,
    "Qty" : 2,
    "Total Bought" : SGB_buying_time * 2,
    "Total Current" : gold_price_per_gram * 2,
    "Up%^ ✨" : round((gold_price_per_gram/SGB_buying_time) *100-100,2)
})
gold_SGB["Today"] = pd.to_datetime(gold['Today'])
gold_SGB["Profit"] = gold_SGB["Total Current"] - gold_SGB["Total Bought"]
gold_SGB
# Out:
#        Today  Buying Price  Current Price  Qty  Total Bought  Total Current  \
# 0 2024-11-13          6213         7476.6    2         12426        14953.2
#
#    Up%^ ✨  Profit
# 0   20.34  2527.2

# %%
#Overall Gold Table

ov_gold = pd.DataFrame({
    'Today' :  [date.today()],
    'Bought At' : gpay_goldVault_buyingTime + (SGB_buying_time * 2),
    'Curr Valuation' : round(gpay_goldVault + (gold_price_per_gram * 2),2),
    'Profit ✨^' : tot_gold_prof
})
ov_gold['Today'] = pd.to_datetime(gold['Today'])
ov_gold["Up%^ ✨"] = round(ov_gold["Curr Valuation"] / ov_gold["Bought At"] * 100 - 100,2)
ov_gold
# Out:
#        Today  Bought At  Curr Valuation  Profit ✨^  Up%^ ✨
# 0 2024-11-13    19308.0        23677.64    4369.64   22.63

# %%
#Monthly regular-expenses
exp = pd.DataFrame({
    "Particulars": ["LiquiEMI", "Gas", "Rent", "Wifi", "Cable", "Misc"],
    "Amount": [10583.33, 805, 5000, 1250, 350, 2000]
})
exp = pd.concat([exp, pd.DataFrame({'Particulars':['Total Exp'], 'Amount': [exp['Amount'].sum()]})])
exp
# Out:
#   Particulars    Amount
# 0    LiquiEMI  10583.33
# 1         Gas    805.00
# 2        Rent   5000.00
# 3        Wifi   1250.00
# 4       Cable    350.00
# 5        Misc   2000.00
# 0   Total Exp  19988.33

# %%
import plotly.express as px
fig = px.bar(exp, x='Particulars', y='Amount', title='Expenditure', text=exp['Amount'].apply(lambda x: f'{x:,.02f}'), color_discrete_sequence=['#334783'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
